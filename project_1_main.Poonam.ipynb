# %%
# import libraries
import os
import csv
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# read in files
student_df = pd.read_csv("Resources/student data.csv")
academic_performance_df = pd.read_csv("Resources/Effects on Academic Performance.csv")

# %%
# CLEANING DATA

# %%
# show column names
student_columns = student_df.columns
student_columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
student_df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# 3                     Yes                   No                        No
# 4                      No                   No                        No
#
#   Did you seek any specialist for a treatment?
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No

# %%
# rename columns
student_df.columns = [ 'Timestamp','Gender', 'Age', 'Course',
       'Year', 'GPA', 'Marital_status',
       'Depression', 'Anxiety',
       'Panic_attack',
       'Specialist_visit']

# %%
# delete timestamp column
del student_df['Timestamp']

# %%
student_df.head()
# Out:
#    Gender   Age             Course    Year          GPA Marital_status  \
# 0  Female  18.0        Engineering  year 1  3.00 - 3.49             No
# 1    Male  21.0  Islamic education  year 2  3.00 - 3.49             No
# 2    Male  19.0                BIT  Year 1  3.00 - 3.49             No
# 3  Female  22.0               Laws  year 3  3.00 - 3.49            Yes
# 4    Male  23.0       Mathemathics  year 4  3.00 - 3.49             No
#
#   Depression Anxiety Panic_attack Specialist_visit
# 0        Yes      No          Yes               No
# 1         No     Yes           No               No
# 2        Yes     Yes          Yes               No
# 3        Yes      No           No               No
# 4         No      No           No               No

# %%
# count how many total students
total_students = len(student_df["GPA"])
total_students
# Out:
# 101

# %%
# make sure every column has same count
student_df.count()
# Out:
# Gender              101
# Age                 100
# Course              101
# Year                101
# GPA                 101
# Marital_status      101
# Depression          101
# Anxiety             101
# Panic_attack        101
# Specialist_visit    101
# dtype: int64

# %%
# see data types
student_df.dtypes
# Out:
# Gender               object
# Age                 float64
# Course               object
# Year                 object
# GPA                  object
# Marital_status       object
# Depression           object
# Anxiety              object
# Panic_attack         object
# Specialist_visit     object
# dtype: object

# %%
# count male vs female
student_df["Gender"].value_counts()
# Out:
# Female    75
# Male      26
# Name: Gender, dtype: int64

# %%
student_df
# Out:
#                Timestamp  Gender   Age              Course    Year  \
# 0         8/7/2020 12:02  Female  18.0         Engineering  year 1
# 1         8/7/2020 12:04    Male  21.0   Islamic education  year 2
# 2         8/7/2020 12:05    Male  19.0                 BIT  Year 1
# 3         8/7/2020 12:06  Female  22.0                Laws  year 3
# 4         8/7/2020 12:13    Male  23.0        Mathemathics  year 4
# ..                   ...     ...   ...                 ...     ...
# 96   13/07/2020 19:56:49  Female  21.0                 BCS  year 1
# 97   13/07/2020 21:21:42    Male  18.0         Engineering  Year 2
# 98   13/07/2020 21:22:56  Female  19.0            Nursing   Year 3
# 99   13/07/2020 21:23:57  Female  23.0    Pendidikan Islam  year 4
# 100  18/07/2020 20:16:21    Male  20.0  Biomedical science  Year 2
#
#              GPA Marital_status Depression Anxiety Panic_attack  \
# 0    3.00 - 3.49             No        Yes      No          Yes
# 1    3.00 - 3.49             No         No     Yes           No
# 2    3.00 - 3.49             No        Yes     Yes          Yes
# 3    3.00 - 3.49            Yes        Yes      No           No
# 4    3.00 - 3.49             No         No      No           No
# ..           ...            ...        ...     ...          ...
# 96   3.50 - 4.00             No         No     Yes           No
# 97   3.00 - 3.49             No        Yes     Yes           No
# 98   3.50 - 4.00            Yes        Yes      No          Yes
# 99   3.50 - 4.00             No         No      No           No
# 100  3.00 - 3.49             No         No      No           No
#
#     Specialist_visit
# 0                 No
# 1                 No
# 2                 No
# 3                 No
# 4                 No
# ..               ...
# 96                No
# 97                No
# 98                No
# 99                No
# 100               No
#
# [101 rows x 11 columns]

# %%
#Count Mental Stress cases
total_Depression_cases=student_df[["Depression"]].value_counts()
total_Panic_cases=student_df[["Panic_attack"]].value_counts()
total_anxiety_cases=student_df[["Anxiety"]].value_counts()
print(total_Depression_cases) 
print(total_Panic_cases)
print(total_anxiety_cases)

#Replace yes/No by 0 and 1 
student_df.Depression.replace(('Yes', 'No'), (1, 0), inplace=True)
student_df.Panic_attack.replace(('Yes', 'No'), (1, 0), inplace=True)
student_df.Anxiety.replace(('Yes', 'No'), (1, 0), inplace=True)

student_df
#print(student_df.groupby('Course')[['Depression', 'Panic_attack','Anxiety']].sum())
# Out:
# Depression
# 0             66
# 1             35
# dtype: int64
# Panic_attack
# No              68
# Yes             33
# dtype: int64
# Anxiety
# No         67
# Yes        34
# dtype: int64
#                Timestamp  Gender   Age              Course    Year  \
# 0         8/7/2020 12:02  Female  18.0         Engineering  year 1
# 1         8/7/2020 12:04    Male  21.0   Islamic education  year 2
# 2         8/7/2020 12:05    Male  19.0                 BIT  Year 1
# 3         8/7/2020 12:06  Female  22.0                Laws  year 3
# 4         8/7/2020 12:13    Male  23.0        Mathemathics  year 4
# ..                   ...     ...   ...                 ...     ...
# 96   13/07/2020 19:56:49  Female  21.0                 BCS  year 1
# 97   13/07/2020 21:21:42    Male  18.0         Engineering  Year 2
# 98   13/07/2020 21:22:56  Female  19.0            Nursing   Year 3
# 99   13/07/2020 21:23:57  Female  23.0    Pendidikan Islam  year 4
# 100  18/07/2020 20:16:21    Male  20.0  Biomedical science  Year 2
#
#              GPA Marital_status  Depression  Anxiety  Panic_attack  \
# 0    3.00 - 3.49             No           1        0             1
# 1    3.00 - 3.49             No           0        1             0
# 2    3.00 - 3.49             No           1        1             1
# 3    3.00 - 3.49            Yes           1        0             0
# 4    3.00 - 3.49             No           0        0             0
# ..           ...            ...         ...      ...           ...
# 96   3.50 - 4.00             No           0        1             0
# 97   3.00 - 3.49             No           1        1             0
# 98   3.50 - 4.00            Yes           1        0             1
# 99   3.50 - 4.00             No           0        0             0
# 100  3.00 - 3.49             No           0        0             0
#
#     Specialist_visit
# 0                 No
# 1                 No
# 2                 No
# 3                 No
# 4                 No
# ..               ...
# 96                No
# 97                No
# 98                No
# 99                No
# 100               No
#
# [101 rows x 11 columns]

# %%
# show agrregate view of total number of mental cases in each mental case category per courses
#df_case_aggregate['depression'] = student_df.groupby('Course')['Depression'].count()
df_case_aggregate= student_df.groupby('Course')[['Depression','Anxiety','Panic_attack']].sum()
df_case_aggregate['Total']=df_case_aggregate['Depression']+df_case_aggregate['Anxiety'],df_case_aggregate['Panic_attack']
df_case_aggregate

#df_case_aggregate['Depression']= df_case_aggregate.apply(lambda x: x[x['Depression'] == 'Yes']['Depression'].sum())


#df1 = df[(df.a>=30) & (df.b==0)].groupby('datetime', as_index=False)['c'].sum()
#df_case_aggregate['Anxiety']= student_df.groupby('Course')[['Anxiety']]. count()
#df_case_aggregate['Panic_attack']= student_df.groupby('Course')[['Panic_attack']]. count()
#df_case_aggregate['Total_mental_cases']=df_case_aggregate['Depression']+df_case_aggregate['Anxiety']+df_case_aggregate['Panic_attack']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hk/gwsj784n0hs0cz0ftwlt3dyc0000gp/T/ipykernel_92417/1626043745.py in <module>
#       2 #df_case_aggregate['depression'] = student_df.groupby('Course')['Depression'].count()
#       3 df_case_aggregate= student_df.groupby('Course')[['Depression','Anxiety','Panic_attack']].sum()
# ----> 4 df_case_aggregate['Total']=df_case_aggregate['Depression']+df_case_aggregate['Anxiety'],df_case_aggregate['Panic_attack']
#       5 df_case_aggregate
#       6
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
#    4539         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4540
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (2) does not match length of index (49)

# %%
# Clean up Course column
student_df['Course'] = student_df['Course'].replace({'Koe': 'KOE','koe': 'KOE'})
student_df['Course'] = student_df['Course'].replace({'benl': 'BENL', 'Benl': 'BENL'})
student_df['Course'] = student_df['Course'].replace({'engin': 'Engineering','Engine': 'Engineering'})
student_df['Course'] = student_df['Course'].replace({'KIRKHS': 'Kirkhs'})
student_df['Course'] = student_df['Course'].replace({'Islamic education': 'Islamic Education'})
student_df['Course'] = student_df['Course'].replace({'Laws': 'Law'})
student_df['Course'] = student_df['Course'].replace({'Pendidikan islam': 'Pendidikan Islam', 'Pendidikan Islam ': 'Pendidikan Islam'})
student_df['Course'] = student_df['Course'].replace({'Diploma Nursing': 'Nursing', 'Nursing ': 'Nursing'})
student_df['Course'] = student_df['Course'].replace({'Fiqh' : 'Fiqh Fatwa ', 'Fiqh Fatwa': 'Fiqh Fatwa'})
student_df['Course'] = student_df['Course'].replace({'Econs' : 'Econ'})
student_df['Course'] = student_df['Course'].replace({'Irkhs' : 'Kirkhs'})
student_df['Course'] = student_df['Course'].replace({'ENM' : 'KENMS'})
student_df['Course'] = student_df['Course'].replace({'psychology' : 'Psychology'})

# %%
student_df["Course"].value_counts()
# Out:
# Engineering                20
# BCS                        18
# BIT                        10
# KOE                         6
# Biomedical science          4
# Law                         3
# Pendidikan Islam            3
# BENL                        3
# Kirkhs                      3
# Psychology                  3
# KENMS                       2
# Nursing                     2
# Islamic Education           2
# Human Sciences              1
# Malcom                      1
# Kop                         1
# Radiography                 1
# Biotechnology               1
# Communication               1
# Econ                        1
# Fiqh fatwa                  1
# DIPLOMA TESL                1
# MHSC                        1
# TAASL                       1
# CTS                         1
# IT                          1
# ALA                         1
# Usuluddin                   1
# Business Administration     1
# Banking Studies             1
# Marine science              1
# Accounting                  1
# Human Resources             1
# Mathemathics                1
# Fiqh Fatwa                  1
# Name: Course, dtype: int64

# %%
# clean up Year column
student_df["Year"].value_counts()
# Out:
# year 1    41
# Year 3    19
# Year 2    16
# year 2    10
# year 4     8
# year 3     5
# Year 1     2
# Name: Year, dtype: int64

# %%
student_df['Year'] = student_df['Year'].replace({'year 1': 'Year 1'})
student_df['Year'] = student_df['Year'].replace({'year 2': 'Year 2'})
student_df['Year'] = student_df['Year'].replace({'year 3': 'Year 3'})

# %%
student_df["Year"].value_counts()
# Out:
# Year 1    43
# Year 2    26
# Year 3    24
# year 4     8
# Name: Year, dtype: int64

# %%
# clean up GPA column
student_df["GPA"].value_counts()
# Out:
# 3.50 - 4.00     47
# 3.00 - 3.49     43
# 2.50 - 2.99      4
# 0 - 1.99         4
# 2.00 - 2.49      2
# 3.50 - 4.00      1
# Name: GPA, dtype: int64

# %%
student_df['GPA'] = student_df['GPA'].replace({'3.50 - 4.00 ': '3.50 - 4.00'})

# %%
student_df["GPA"].value_counts()
# Out:
# 3.50 - 4.00    48
# 3.00 - 3.49    43
# 2.50 - 2.99     4
# 0 - 1.99        4
# 2.00 - 2.49     2
# Name: GPA, dtype: int64

# %%
##### OTHER SPREADSHEET

# %%
academic_performance_df.head()
# Out:
#   Gender:              Age:     Educational Level  \
# 0    Male    19 to 24 years  College - Bachelor's
# 1    Male    19 to 24 years  College - Bachelor's
# 2  Female  18 years or less           High School
# 3  Female  18 years or less           High School
# 4    Male  18 years or less           High School
#
#    Little interest or pleasure in doing things   \
# 0                                             3
# 1                                             2
# 2                                             2
# 3                                             3
# 4                                             1
#
#    Feeling down, depressed, or hopeless  \
# 0                                     2
# 1                                     1
# 2                                     2
# 3                                     1
# 4                                     2
#
#    Trouble falling or staying asleep, or sleeping too much  \
# 0                                                  4
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Feeling tired or having little energy  Poor appetite or overeating  \
# 0                                      4                            3
# 1                                      1                            1
# 2                                      2                            1
# 3                                      3                            3
# 4                                      3                            1
#
#    Feeling bad about yourself or that you are a failure or not have let yourself or your family down  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Trouble concentrating on things, such as reading the newspaper or watching television  \
# 0                                                  4
# 1                                                  1
# 2                                                  2
# 3                                                  1
# 4                                                  3
#
#    Moving or speaking so slowly that other people could have noticed Or being so restless that you have been moving around a lot more than usual  \
# 0                                                  3
# 1                                                  1
# 2                                                  2
# 3                                                  1
# 4                                                  1
#
#    Thoughts that you would be better off dead or of hurting yourself in some way  \
# 0                                                  2
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  1
#
#   Do you have part-time or full-time job?   \
# 0                                Part time
# 1                                Part time
# 2                                       No
# 3                                       No
# 4                                Part time
#
#   Which of the following best describes your term-time accommodation?  \
# 0                                Home (with parents)
# 1                       University hall of residence
# 2                                Home (with parents)
# 3                                Home (with parents)
# 4                                Home (with parents)
#
#   How many hours do you spend studying each day?  \
# 0                                    2 - 4 hours
# 1                                    1 - 2 hours
# 2                                    1 - 2 hours
# 3                                    1 - 2 hours
# 4                                    1 - 2 hours
#
#   How many of the electronic gadgets (e.g. mobile phone, computer, laptop, PSP, PS4, Wii, etc.) do you have in your home or your student accommodation/mess/hall?  \
# 0                                              4 - 6
# 1                                              1 - 3
# 2                                              1 - 3
# 3                                        More than 6
# 4                                              4 - 6
#
#   How many hours do you spend on social media per day?  \
# 0                                  More than 4 Hours
# 1                                        1 - 2 Hours
# 2                                  More than 4 Hours
# 3                                        2 - 4 Hours
# 4                                  More than 4 Hours
#
#    Your Last Semester GPA:
# 0                      2.30
# 1                      2.70
# 2                      2.97
# 3                      2.74
# 4                      3.37

# %%
# CLEANING DATA

# %%
# rename columns
rename_academic_df = academic_performance_df.rename(columns = {'Gender:':'gender', 'Age:':'age',
                                     'Educational Level':'educational_level',
                                     'Little interest or pleasure in doing things ':'interest_level',
                                     'Feeling down, depressed, or hopeless':'depressed_level',
                                     'Trouble falling or staying asleep, or sleeping too much':'sleepy_level',
                                     'Feeling tired or having little energy':'energy_level',
                                     'Poor appetite or overeating':'appetite_level',
                                     'Feeling bad about yourself or that you are a failure or not have let yourself or your family down':'self_worth_level',
                                     'Trouble concentrating on things, such as reading the newspaper or watching television':'concentrating_level',
                                     'Moving or speaking so slowly that other people could have noticed Or being so restless that you have been moving around a lot more than usual':'restless_level',
                                     'Thoughts that you would be better off dead or of hurting yourself in some way':'suicidal_level',
                                     'Do you have part-time or full-time job? ':'employment',
                                     'Which of the following best describes your term-time accommodation?':'housing_situation',
                                     'How many hours do you spend studying each day?':'studing_spending',
                                     'How many of the electronic gadgets (e.g. mobile phone, computer, laptop, PSP, PS4, Wii, etc.) do you have in your home or your student accommodation/mess/hall?':'electronic_devices',
                                     'How many hours do you spend on social media per day?':'social_media_time',
                                     'Your Last Semester GPA: ':'GPA'})

# %%
# look at count to ensure each column has same number of rows 
rename_academic_df.count()
# Out:
# gender                 352
# age                    352
# educational_level      352
# interest_level         352
# depressed_level        352
# sleepy_level           352
# energy_level           352
# appetite_level         352
# self_worth_level       352
# concentrating_level    352
# restless_level         352
# suicidal_level         352
# employment             352
# housing_situation      352
# studing_spending       352
# electronic_devices     352
# social_media_time      352
# GPA                    352
# dtype: int64

# %%
# filter to show only "College - Bachelor's"
rename_academic_df['educational_level'].value_counts()
# Out:
# College - Bachelor's    204
# High School             124
# Master                   24
# Name: educational_level, dtype: int64

# %%
bachelors_df = rename_academic_df.loc[rename_academic_df['educational_level'] == "College - Bachelor's"]
bachelors_df.head()
# Out:
#     gender             age     educational_level  interest_level  \
# 0     Male  19 to 24 years  College - Bachelor's               3
# 1     Male  19 to 24 years  College - Bachelor's               2
# 6   Female  19 to 24 years  College - Bachelor's               2
# 8   Female  19 to 24 years  College - Bachelor's               3
# 10  Female  19 to 24 years  College - Bachelor's               2
#
#     depressed_level  sleepy_level  energy_level  appetite_level  \
# 0                 2             4             4               3
# 1                 1             2             1               1
# 6                 2             3             3               1
# 8                 1             4             3               1
# 10                4             4             3               2
#
#     self_worth_level  concentrating_level  restless_level  suicidal_level  \
# 0                  3                    4               3               2
# 1                  1                    1               1               1
# 6                  1                    2               2               1
# 8                  2                    1               1               1
# 10                 3                    4               1               3
#
#    employment             housing_situation studing_spending  \
# 0   Part time           Home (with parents)      2 - 4 hours
# 1   Part time  University hall of residence      1 - 2 hours
# 6   Part time           Home (with parents)      1 - 2 hours
# 8   Full time           Home (with parents)      1 - 2 hours
# 10         No           Home (with parents)      1 - 2 hours
#
#    electronic_devices  social_media_time   GPA
# 0               4 - 6  More than 4 Hours  2.30
# 1               1 - 3        1 - 2 Hours  2.70
# 6               4 - 6        2 - 4 Hours  2.75
# 8               4 - 6  More than 4 Hours  3.97
# 10              1 - 3  More than 4 Hours  2.97

# %%
# reset index 
bachelors_df = bachelors_df.reset_index(drop = True)

# %%
#bachelors_df
student_df.head()
# Out:
#         Timestamp  Gender   Age             Course    Year          GPA  \
# 0  8/7/2020 12:02  Female  18.0        Engineering  year 1  3.00 - 3.49
# 1  8/7/2020 12:04    Male  21.0  Islamic education  year 2  3.00 - 3.49
# 2  8/7/2020 12:05    Male  19.0                BIT  Year 1  3.00 - 3.49
# 3  8/7/2020 12:06  Female  22.0               Laws  year 3  3.00 - 3.49
# 4  8/7/2020 12:13    Male  23.0       Mathemathics  year 4  3.00 - 3.49
#
#   Marital_status Depression Anxiety Panic_attack Specialist_visit
# 0             No        Yes      No          Yes               No
# 1             No         No     Yes           No               No
# 2             No        Yes     Yes          Yes               No
# 3            Yes        Yes      No           No               No
# 4             No         No      No           No               No

# %%
#Analysing Major’s effect on student stress level


# rename columns
student_df.columns = ['Timestamp', 'Gender', 'Age', 'Course',
       'Year', 'GPA', 'Marital_status',
       'Depression', 'Anxiety',
       'Panic_attack',
       'Specialist_visit']

student_df.head()

# Calculating the Stress Level of each Course 


Depression_count=0
Anxiety_count=0
Panic_attack=0


#Giving ranking of 1 if depression, Anxiety, Panic-Attack value is yes otherwise giving ranking of 0  
for rows in student_df:
    student_df.loc[student_df["Depression"]== 'No', 'Depression']= 0
    student_df.loc[student_df["Depression"]== 'Yes', 'Depression']= 1
    student_df.loc[student_df["Anxiety"]== 'No', 'Anxiety']= 0
    student_df.loc[student_df["Anxiety"]== 'Yes', 'Anxiety']= 1
    student_df.loc[student_df["Panic_attack"]== 'No', 'Panic_attack']= 0
    student_df.loc[student_df["Panic_attack"]== 'Yes', 'Panic_attack']= 1
        
    
student_df.head()
    
   
 # Create new column 'sumxyz' to store aggregate result
student_df['sumstress'] = 0

# Loop to generate new column with aggregation
for Course in student_df['Course'].unique():
    df_temp = stident_df[student_df['Course'] == Course]
    student.df['sumstress'][data['Course'] == Course] = df_temp['Depression'] + df_temp['Anxiety'] + df_temp['Panic_attack'] 

# Print all distinct values of column 'a' along with the total sum of x,y,z for each
for Course in student_df['Course'].unique():
    print('Total Stress for '+ Course + ' is:', student_df[student_df['Course'] == Course]['sumstress'].sum())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hk/gwsj784n0hs0cz0ftwlt3dyc0000gp/T/ipykernel_15000/696026873.py in <module>
#       3
#       4 # rename columns
# ----> 5 student_df.columns = ['Timestamp', 'Gender', 'Age', 'Course',
#       6        'Year', 'GPA', 'Marital_status',
#       7        'Depression', 'Anxiety',
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
#     770         self._clear_item_cache()
#     771
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     212     def set_axis(self, axis: int, new_labels: Index) -> None:
#     213         # Caller is responsible for ensuring we have an Index object.
# --> 214         self._validate_set_axis(axis, new_labels)
#     215         self.axes[axis] = new_labels
#     216
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      67
#      68         elif new_len != old_len:
# ---> 69             raise ValueError(
#      70                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      71                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 12 elements, new values have 11 elements
